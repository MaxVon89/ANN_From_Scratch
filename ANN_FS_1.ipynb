# %% [markdown]
# # Artificial Neural Network
# ## From Scratch
#
#
# ## Basics
#
# ### Dataset:
#
#     MNIST
#
#         'm' no. of 28p x 28p (784 total pixels) images
#
#         Value Range: (0,255)
#
#         Matrix X (m,784) =
#
#             | x(1,1) x(1,2) ... x(1,784) |
#             | x(2,1) x(2,2) ... x(2,784) |
#             | .      .      ... .        |
#             | .      .      ... .        |
#             | .      .      ... .        |
#             | x(m,1) x(m,2) ... x(m,784) |
#
#
#         X = X^T
#
#         Row <-> Coloumn
#
# ### ANN
#
#     Total layers: 4 (1 x input, 2 x hidden, 1 x output)
#
# #### Layer 0 (Input)
#     784 nodes
#
# #### Layer 1 (Hidden (1))
#     10 nodes
#
# #### Layer 2 (Hidden (2))
#     10 nodes
#
# #### Layer 3 (Output)
#     1 node

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt


df = pd.read_csv("D:\\Datasets\\artificialNeuralNetwork\\sample_submission.csv")
df.tail()
# Out:
#        ImageId  Label
# 27995    27996      0
# 27996    27997      0
# 27997    27998      0
# 27998    27999      0
# 27999    28000      0

# %%
#Need the data as Numpy arrays

df = np.array(df)
# df

m,n = df.shape
print([m,n])

np.random.shuffle(df)
df
# Out:
# [28000, 2]
# array([[19299,     0],
#        [ 1768,     0],
#        [17342,     0],
#        ...,
#        [24411,     0],
#        [ 2499,     0],
#        [27284,     0]], shape=(28000, 2))
